# %%
import pandas as pd
import numpy as np
import os
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
count_class = pd.value_counts(df['Class'])
count_class.plot(kind='bar')
plt.title('Credit Card Fraud Class')
plt.xlabel('Class')
plt.ylabel('Number of transactions')
# Out:
# Text(0, 0.5, 'Number of transactions')

# %%
not_fraud = df[df['Class'] == 0]
fraud = df[df['Class'] == 1]
print(fraud.shape, not_fraud.shape)
# Out:
# (492, 31) (284315, 31)

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
not_fraud.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fig,(ax1,ax2)=plt.subplots(2,1, sharex=True)
ax1.hist(fraud.Amount, bins = 20)
ax1.set_title('Fraud')
ax2.hist(not_fraud.Amount, bins = 20)
ax2.set_title("Not Fraud")
plt.xlabel('Amount($)')
plt.ylabel('Number of transactions')
fig.suptitle('Amount per transaction by Class')
plt.xlim((0,30000))
plt.yscale('log')
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(2,1, sharex= True)
ax1.scatter(fraud.Time, fraud.Amount)
ax1.set_title('Fraud')
ax2.scatter(not_fraud.Time, not_fraud.Amount)
ax2.set_title("Not Fraud")
plt.xlabel('Time (seconds)')
plt.ylabel('Amount')
fig.suptitle('Time of Transaction and Amount')
plt.show()

# %%
plt.figure(figsize = (20,20))
plt.title('Correlation Matrix')
cor = df.corr()
sns.heatmap(cor, xticklabels = cor.columns, yticklabels = cor.columns, linewidths = .5, annot = True, cmap = 'Blues')
plt.show()

# %%
import gc
from datetime import datetime 
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn import svm

# %%
data_df = df.columns.values
n = 0
class_0 = df.loc[df['Class'] == 0]
class_1 = df.loc[df['Class'] == 1]

sns.set_style('whitegrid')
plt.figure()
fig, ax = plt.subplots(8,4, figsize = (16,28))

for i in data_df:
    n +=1
    plt.subplot(8,4,n)
    sns.kdeplot(class_0[i], bw = 0.5, label = 'Class = 0')
    sns.kdeplot(class_1[i], bw = 0.5, label = 'Class =1')
    plt.xlabel(i, fontsize = 12)
    locs, labels = plt.xticks()
    plt.tick_params(axis = 'both', which = 'major', labelsize = 12)
plt.show()
# Out:
# /var/folders/rl/fmms2yhn74j03y82v9swjm3r0000gn/T/ipykernel_31270/3701428826.py:13: UserWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`.
# Setting `bw_method=0.5`, but please see the docs for the new parameters
# and update your code. This will become an error in seaborn v0.13.0.
#
#   sns.kdeplot(class_0[i], bw = 0.5, label = 'Class = 0')
# /var/folders/rl/fmms2yhn74j03y82v9swjm3r0000gn/T/ipykernel_31270/3701428826.py:14: UserWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`.
# Setting `bw_method=0.5`, but please see the docs for the new parameters
# and update your code. This will become an error in seaborn v0.13.0.
#
#   sns.kdeplot(class_1[i], bw = 0.5, label = 'Class =1')
# /var/folders/rl/fmms2yhn74j03y82v9swjm3r0000gn/T/ipykernel_31270/3701428826.py:13: UserWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`.
# ...

# %%
dependent = 'Class'
predictors = ['Time','V1','V2','V3','V4','V5','V6','V7','V8','V9','V10','V11','V12','V13','V14','V15','V16','V17','V18','V19','V20','V21', 'V22','V23','V24','V25','V26','V27','V28','Amount']

# %%
train_df, test_df = train_test_split(df, test_size = 0.2, random_state = 2018, shuffle = True)
train_df, valid_df = train_test_split(train_df, test_size = 0.2, random_state = 2018, shuffle = True)

# %%
clf = RandomForestClassifier(n_jobs = 4,
                            random_state = 2024,
                            criterion = 'gini',
                            n_estimators = 100,
                            verbose = False)

# %%
clf.fit(train_df[predictors], train_df[dependent].values)
# Out:
# RandomForestClassifier(n_jobs=4, random_state=2024, verbose=False)

# %%
yhat = clf.predict(valid_df[predictors])

# %%
df1 = pd.DataFrame({'Feature': predictors, 'Feature importance': clf.feature_importances_})
df1 = df1.sort_values(by = 'Feature importance', ascending = True)
plt.figure(figsize = (10,5))
plt.title('Feature Importances', fontsize = 12)
s1 = sns.barplot(x = 'Feature', y = 'Feature importance', data = df1)
s1.set_xticklabels(s1.get_xticklabels(), rotation = 90)
plt.show()

# %%
confusion_matrix = pd.crosstab(valid_df[dependent].values, yhat, rownames = ['True'], colnames = ['Predicted'])
fig, ax1 = plt.subplots(ncols = 1, figsize = (7,7))
sns.heatmap(confusion_matrix,
           xticklabels = ['Not Fraud', 'Fraud'],
           yticklabels = ['Not Fraud', 'Fraud'],
           annot = True, ax = ax1,
           linewidths = .5, linecolor = 'Darkblue', cmap = 'Blues')
plt.title('Confusion Matrix', fontsize = 12)
plt.show()

# %%
roc_auc_score(valid_df[dependent].values, yhat)
# Out:
# 0.843049279007356
